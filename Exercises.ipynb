# %% [markdown]
# ### Given a number, replace all 0's into 1's.

# %%
value = input()
value = str(value)
indices = which(value) == "0"
value[indices] = "1"
return(value)
# Out:
#  0201
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 value = input()
#       2 value = str(value)
# ----> 3 indices = which(value) == "0"
#       4 value[indices] = "1"
#       5 return(value)
#
# NameError: name 'which' is not defined
